# %%
# import cv2
# import matplotlib.pyplot as plt
# import os
# path = "../../experiment8/"
# path_to_plots = path + "plots/Centrality/"

# video_name = path.strip("./") +"_deg_con_vid.mp4"

# path_to_pics = path_to_plots + "degree_connectivity/annd_all_slices/jpgs/" 

# num_pics = len(os.listdir(path_to_pics))
# pic_names = [f"slice_{s}.jpg" for s in range(1,num_pics +1)]


# frame = cv2.imread(path_to_plots + "degree_connectivity/annd_all_slices/jpgs/slice_1.jpg")
# (height, width) = frame.shape[:2]
# size_f = (width, height)


# video = cv2.VideoWriter(video_name, 0, 1, size_f)

# # for image in images:
# #     video.write(cv2.imread(os.path.join(path_to_pics, image)))

# # cv2.destroyAllWindows()
# # video.release()

import matplotlib.pyplot as plt
import numpy as np


t = np.linspace(0,2*np.pi,1000)

plt.plot(t,np.sin(t), color = "coral")
plt.plot(t,np.cos(t), color = "cyan")
plt.plot(t,2*t, color = "fuchsia")
plt.show()
