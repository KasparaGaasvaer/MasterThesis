# %%
import numpy as np
import matplotlib.pyplot as plt 

N = 1000

t = np.linspace(0,2*np.pi,N)
f = np.sin(t)

fig, ax = plt.subplots()
ax.plot(t,f)
x_l = ax.get_xticks()
new = [r"$10^{%.1f}$"%x for x in x_l]
ax.set_xticklabels(new)
plt.show()
# Out:
# /tmp/ipykernel_56853/1216897200.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(new)
